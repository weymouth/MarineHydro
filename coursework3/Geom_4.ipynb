# %% [markdown]
# ## Project 4: Sail and fairing
#
# #### 2D analysis of a thin foil behind a fairing
#
# ![Masts.svg.png](attachment:Masts.svg.png)
#
# ---
#
# ##### Geometry
#
# The lift and drag of a sail depends on the fairing applied to the mast in front of it. Model this using an `open` vortex sheet of length $c$ for the sail, and a `closed` vortex sheet just upstream of length $d$ and thickness $t\approx0.05c$ for the fairing. The sheet has some camber $m$ and the fairing should align with the angle of the leading edge of the sheet, as in the images above.
#
# ##### Parametric study
#
# You will study the impact of the relative size of the sheet and fairing in the range $0\le d/c\le 0.25$ over a camber range of $0 \le m/c \le 0.2$. Make sure the geometry and resulting flow are reasonable across the parameter range.
#
# ##### Performance metrics
#
# Predict drag on the mast and lift on the combined mast/sheet geometry. Try plotting the forces against $d/c$ or another factor which might help the analysis. Determine the added mass in $x,y$ over the parameter range. Make sure to explain and validate any code you develop for these metrics.
#
# ##### Discussion
#
# Discuss how you could use your results to determine the optimal values of $d$ and $c$. Discuss the advantages and limitations of this analysis.
